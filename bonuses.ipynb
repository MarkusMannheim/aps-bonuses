# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
import seaborn as sns

sns.set_style("darkgrid")
sns.set_theme()
sns.set_context("paper", font_scale=1.5, rc={"lines.linewidth": 3.5})

data = pd.read_csv("./bonuses.csv")
grouped_data = data.groupby("year").sum()
grouped_data["ratio"] = grouped_data["paid"] / grouped_data["employees"]

data = data[data["year"] == 2019]
data
# Out:
#     year      band  employees  paid      min         P5         Q1    median  \
# 0   2019      SES3        123     4   148.00  7464.0285  19209.750  31905.00
# 1   2019      SES2        553    27  5663.94  8468.3000  20000.000  22192.39
# 2   2019      SES1       2022    83  2725.00  2867.4000   8152.225  11329.00
# 3   2019       EL2      11167  1552    14.00  1421.0000   1421.000   1563.00
# 4   2019       EL1      25601  3178    11.00   920.0000   1150.000   1150.00
# 5   2019      APS6      31920  3559    27.00   736.0000    922.000    922.00
# 6   2019      APS5      19915  2240    52.00   662.7000    789.000    789.00
# 7   2019      APS4      26354  1152    53.00   455.9500    733.000    733.00
# 8   2019      APS3      12024   949    74.00   435.0000    725.000    725.00
# 9   2019      APS2       1858   418   309.00   533.0500    725.000    725.00
# 10  2019      APS1        482    39   309.00   471.7000    725.000    725.00
# ...

# %%
watches = 0
watches = watches + data.loc[12, "paid"]
watches = watches + round((data.loc[13, "Q1"] - 20000) / (data.loc[13, "Q1"] - data.loc[13, "P5"]) * (round(data.loc[13, "paid"] * .25) - round(data.loc[13, "paid"] * .05))) + round(data.loc[13, "paid"] * .75)
watches = watches + round((data.loc[14, "P95"] - 20000) / (data.loc[14, "P95"] - data.loc[14, "Q3"]) * (round(data.loc[14, "paid"] * .95) - round(data.loc[14, "paid"] * .75))) + round(data.loc[14, "paid"] * .05)
watches = watches + round((data.loc[15, "max"] - 20000) / (data.loc[15, "max"] - data.loc[15, "P95"]) * (round(data.loc[15, "paid"] * 1) - round(data.loc[15, "paid"] * .95))) + round(data.loc[15, "paid"] * .0)
watches = watches + round((data.loc[16, "max"] - 20000) / (data.loc[16, "max"] - data.loc[16, "P95"]) * (round(data.loc[16, "paid"] * 1) - round(data.loc[16, "paid"] * .95))) + round(data.loc[16, "paid"] * .0)
watches = watches + round((data.loc[17, "max"] - 20000) / (data.loc[17, "max"] - data.loc[17, "P95"]) * (round(data.loc[17, "paid"] * 1) - round(data.loc[17, "paid"] * .95))) + round(data.loc[17, "paid"] * .0)
watches = watches + round((data.loc[18, "max"] - 20000) / (data.loc[18, "max"] - data.loc[18, "P95"]) * (round(data.loc[18, "paid"] * 1) - round(data.loc[18, "paid"] * .95))) + round(data.loc[18, "paid"] * .0)
watches
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/.local/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2894             try:
# -> 2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# KeyError: 12
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-84-f523f64e5442> in <module>
#       1 watches = 0
# ...

# %%
watches = 0
watches = watches + data.loc[12, "paid"]
watches = watches + round(data.loc[13, "paid"] * .75) + 1
watches = watches + round(data.loc[14, "paid"] * .05) + 1
watches = watches + round(data.loc[15, "paid"] * .00) + 1
watches = watches + round(data.loc[16, "paid"] * .00) + 1
watches = watches + round(data.loc[17, "paid"] * .00) + 1
watches = watches + round(data.loc[18, "paid"] * .00) + 1
watches
# Out:
# 35

# %%
data["paid"].sum()
# Out:
# 13205
